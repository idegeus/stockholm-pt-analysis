# %%
from google.transit import gtfs_realtime_pb2
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import contextily as cx
import matplotlib.pyplot as plt
from glob import glob
from tqdm.notebook import tqdm
import zipfile

# %% [markdown]
# ## Read in GTFS Static Data

# %%
# Trips and routes.
trips = pd.read_csv('./data/2-working-data/all-trips.csv', index_col=0)
trips.trip_id = trips.trip_id.astype(str)
trips = trips.drop(columns=['service_id', 'trip_headsign', 'agency_id', 'route_type', 'route_long_name'])

# Filter only Tvärbanan
trips_selected = trips[trips.route_desc.str.contains('Tvär') == True]
trips_selected.sample(5)
# Out:
#                route_id            trip_id  direction_id  shape_id  \
# 27086  9011001003100000  14010000595317403             1       472
# 26974  9011001003100000  14010000591806962             1       471
# 26921  9011001003100000  14010000591807867             1       471
# 26524  9011001003000000  14010000574856641             0       465
# 27059  9011001003100000  14010000595315300             1       472
#
#       route_short_name route_desc
# 27086               31  Tvärbanan
# 26974               31  Tvärbanan
# 26921               31  Tvärbanan
# 26524               30  Tvärbanan
# 27059               31  Tvärbanan

# %%
# Trips and routes.
stops = pd.read_csv('./data/2-working-data/tvarbanan-stops.csv', index_col=0)
stops.stop_id = stops.stop_id.astype(str)

# Change to GeoDataFrame
stops['geometry'] = stops.apply(lambda x: Point(x.stop_lon, x.stop_lat), axis=1)
stops = stops.drop(columns=['location_type', 'stop_lat', 'stop_lon', 'platform_code', 'parent_station'])
stops = gpd.GeoDataFrame(stops, crs='EPSG:4326')

# Plot out and show stops
ax = stops.plot()
cx.add_basemap(ax, crs=stops.crs)

stops.head()
# Out:
# /Users/ivo/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:112: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   values = construct_1d_object_array_from_listlike(values)
#                stop_id     stop_name                   geometry
# 7698  9022001004501001  Gullmarsplan  POINT (18.08037 59.29942)
# 7699  9022001004501002  Gullmarsplan  POINT (18.08026 59.29957)
# 7700  9022001004503001        Globen  POINT (18.07613 59.29403)
# 7701  9022001004503002        Globen  POINT (18.07709 59.29421)
# 7702  9022001004505001         Linde  POINT (18.06386 59.29330)

# %% [markdown]
# ## Read in all TripUpdates

# %%
# filenames = glob("./data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/15/*.pb")
filenames = glob("./data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/**/*.pb")

filenames = filenames[:(len(filenames)//4)]

filenames[:5], len(filenames)
# Out:
# (['./data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/03/sl-tripupdates-2021-12-01T03-36-22Z.pb',
#   './data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/03/sl-tripupdates-2021-12-01T03-51-46Z.pb',
#   './data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/03/sl-tripupdates-2021-12-01T03-33-06Z.pb',
#   './data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/03/sl-tripupdates-2021-12-01T03-05-06Z.pb',
#   './data/1-koda-gtfs-rt-extracted/sl/TripUpdates/2021/12/01/03/sl-tripupdates-2021-12-01T03-16-46Z.pb'],
#  1160)

# %%
tu_data = []

for file in tqdm(filenames, miniters=20): 
    
    feed = gtfs_realtime_pb2.FeedMessage()
    with open(file, 'rb') as stream:
        feed.ParseFromString(stream.read())
    
    for e in feed.entity:
        tu_data += [
            (e.trip_update.timestamp, 
             e.trip_update.trip.trip_id,
             e.trip_update.trip.schedule_relationship,
             stop_update.stop_id,
             stop_update.arrival.time, 
             stop_update.arrival.delay, 
             stop_update.departure.time,
             stop_update.departure.delay)
            for stop_update in e.trip_update.stop_time_update
    ]
#     break;
# Out:
#   0%|          | 0/1160 [00:00<?, ?it/s]

# %%
# Incorporate collected data into DataFrame.
tu_df = pd.DataFrame(tu_data, columns=['timestamp', 'trip_id', 'rel', 'stop_id', 
                                    'arrival_ts', 'arrival_delay', 
                                    'departure_ts', 'departure_delay'])
# Parse UNIX Datetime.
tu_df.timestamp    = pd.to_datetime(tu_df.timestamp, unit='s')
tu_df.arrival_ts   = pd.to_datetime(tu_df.arrival_ts, unit='s')
tu_df.departure_ts = pd.to_datetime(tu_df.departure_ts, unit='s')
tu_df
# Out:
#                    timestamp            trip_id  rel           stop_id  \
# 0        2021-12-01 02:35:02  14010000594811385    0  9022001050013002
# 1        2021-12-01 02:35:02  14010000594811385    0  9022001050012002
# 2        2021-12-01 02:35:02  14010000594811385    0  9022001050010001
# 3        2021-12-01 02:35:02  14010000594811385    0  9022001050007002
# 4        2021-12-01 02:35:02  14010000594811385    0  9022001050005002
# ...                      ...                ...  ...               ...
# 10240398 2021-12-01 17:18:26  14010000588473521    0  9022001050602002
# 10240399 2021-12-01 17:18:26  14010000588473521    0  9022001052350001
# 10240400 2021-12-01 17:18:26  14010000588473521    0  9022001052352001
# 10240401 2021-12-01 17:18:26  14010000588473521    0  9022001052354001
# 10240402 2021-12-01 17:18:26  14010000588473521    0  9022001052356001
#
#                   arrival_ts  arrival_delay        departure_ts  \
# ...

# %%
# Merge trips, routes and stop-data into TripUpdate_df. 
tu_df_merged = tu_df.merge(trips, how='left', on='trip_id')
tu_df_merged = tu_df_merged.merge(stops, how='left', on='stop_id')

# Filter on only Tvärbanan and show a little bit. 
tu_df_filtered = tu_df_merged[tu_df_merged.route_desc.str.contains('Tvär') == True]
tu_df_filtered[['timestamp', 'trip_id', 'stop_id', 'arrival_delay', 'departure_delay', 'route_desc', 'stop_name']]
# Out:
#                    timestamp            trip_id           stop_id  \
# 355186   2021-12-01 03:43:35  14010000574674898  9022001004535002
# 355187   2021-12-01 03:43:35  14010000574674898  9022001004525002
# 355188   2021-12-01 03:43:35  14010000574674898  9022001004523002
# 355189   2021-12-01 03:43:35  14010000574674898  9022001004521002
# 355190   2021-12-01 03:43:35  14010000574674898  9022001004519002
# ...                      ...                ...               ...
# 10238635 2021-12-01 17:32:23  14010000592562361  9022001004527002
# 10238636 2021-12-01 17:32:23  14010000592562361  9022001004529002
# 10238637 2021-12-01 17:32:23  14010000592562361  9022001004531002
# 10238638 2021-12-01 17:32:23  14010000592562361  9022001004533002
# 10238639 2021-12-01 17:32:23  14010000592562361  9022001007611002
#
#           arrival_delay  departure_delay route_desc       stop_name
# 355186             -289               24  Tvärbanan    Johannesfred
# ...

# %% [markdown]
# # Delay
# From: https://gtfs.org/realtime/reference/#message-stoptimeupdate
#
# * Positive is a delay
# * Negative is ahead of schedule

# %%
# Delay details of a random trip on a random day at 14:51. 
single = tu_df_filtered[tu_df_filtered.trip_id == '14010000592562361']
single = single.groupby('stop_id').apply(lambda x: x.loc[x.timestamp.idxmax()])
single.sort_values('arrival_ts')
# Out:
#                            timestamp            trip_id  rel  \
# stop_id
# 9022001004549002 2021-12-01 17:53:10  14010000592562361    0
# 9022001004547002 2021-12-01 17:53:10  14010000592562361    0
# 9022001004545002 2021-12-01 17:55:22  14010000592562361    0
# 9022001004543002 2021-12-01 17:58:29  14010000592562361    0
# 9022001004541002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004539002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004537002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004535002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004525002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004523002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004521002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004519002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004517002 2021-12-01 17:58:55  14010000592562361    0
# 9022001004515002 2021-12-01 17:58:55  14010000592562361    0
# ...

# %%
# Only southbound trips. 
groupall = df_filtered[df_filtered.direction_id==0.0]

# Group by trip, then by stop (to select latest update), and then sort by departure time.
groupall = groupall.groupby('trip_id').apply(
    lambda x: x.groupby('stop_id').apply(
        lambda x: x.loc[x.timestamp.idxmax()]).sort_values('departure_ts'))

groupall = groupall.drop(columns=['trip_id', 'stop_id'])
groupall
# Out:
#                                              timestamp  rel  \
# trip_id           stop_id
# 14010000574674898 9022001004535002 2021-12-01 03:52:33    0
#                   9022001004525002 2021-12-01 03:52:33    0
#                   9022001004523002 2021-12-01 03:54:19    0
#                   9022001004521002 2021-12-01 03:55:57    0
#                   9022001004519002 2021-12-01 03:59:18    0
# ...                                                ...  ...
# 14010000592562513 9022001004527002 2021-12-01 19:20:45    0
#                   9022001004529002 2021-12-01 19:20:45    0
#                   9022001004531002 2021-12-01 19:20:45    0
#                   9022001004533002 2021-12-01 19:20:45    0
#                   9022001007611002 2021-12-01 19:20:45    0
#
#                                             arrival_ts  arrival_delay  \
# trip_id           stop_id
# 14010000574674898 9022001004535002 2021-12-01 03:35:11           -289
# ...

# %%
# Sort values
sort_stops = groupall.loc['14010000589843064'].stop_name.reset_index()
groupall['stop_name'] = pd.Categorical(groupall['stop_name'], sort_stops.stop_name)

print(sort_stops.stop_name.to_list())
# Out:
# ['Solna station', 'Solna centrum', 'Solna Business Park', 'Sundbybergs centrum', 'Bällsta bro', 'Karlsbodavägen', 'Norra Ulvsunda', 'Johannesfred', 'Alvik', 'Alviks strand', 'Stora Essingen', 'Gröndal', 'Trekanten', 'Liljeholmen', 'Årstadal', 'Årstaberg', 'Årstafältet', 'Valla torg', 'Linde', 'Globen', 'Gullmarsplan', 'Mårtensdal', 'Luma', 'Sickla kaj', 'Sickla udde', 'Sickla']

# %%
delay_stats = groupall.pivot_table(values='departure_delay', columns='trip_id', index='stop_name')
delay_stats = delay_stats.fillna(0)
delay_stats.plot(figsize=(20,10), legend=False)
# Out:
# <AxesSubplot:xlabel='stop_name'>

# %% [markdown]
# To get realised delay: always take the latest in timestamp per trip-stop combination
# ![afbeelding.png](attachment:afbeelding.png)
#
# # ToDo
# * Average stop delay
# * Variance in stop delay
# * Seeing how much prediction of stop delay is actually realistic: is it too pessimistic or too optimistic? Is it accurate?
# * Seeing if stops exist where trams always arrive early
