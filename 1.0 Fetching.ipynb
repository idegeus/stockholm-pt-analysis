# %%
# !pip install tqdm --quiet

# %%
import requests
from tqdm.notebook import tqdm
import os.path
from calendar import monthrange
import time

# API_KEY = "FpIG19BfekWUFWGPhb5Nl_zIMPA7Z7gI7ZQ1DESEGkk"
API_KEY = "zw_mUBWe3F72OcpgY1j2FjnVQMULgW52uOJzvvdxT6A"

# Note the months to fetch and generate dates
months = [6, 7, 10, 11, 12]
dates = [f"""2021-{month:02}-{(day+1):02}""" for month in months for day in range(monthrange(2022, month)[1])]

# Show last 10 days to fetch
print(len(dates))
dates[-10:]
# Out:
# 153
# ['2021-12-22',
#  '2021-12-23',
#  '2021-12-24',
#  '2021-12-25',
#  '2021-12-26',
#  '2021-12-27',
#  '2021-12-28',
#  '2021-12-29',
#  '2021-12-30',
#  '2021-12-31']

# %%
# Downloading real-time historical data.
# !mkdir -p ./data/0-koda-gtfs-rt/vp/
# !mkdir -p ./data/0-koda-gtfs-rt/tu/
# !open ./data/0-koda-gtfs-rt/tu/

headers = {'accept': 'application/octet-stream'}
iterator = tqdm(dates)
for date in iterator:
    iterator.set_description("Processing %s" % date)

    # Create parameter dictionary including key for this iteration
    params = {'date': date, 'key': API_KEY}

    # Construct filename and output path.
    # If files are already downloaded, we skip this iteration.
    file_path_vp = f"""./data/0-koda-gtfs-rt/vp/{params['date']}.7z"""
    file_path_tu = f"""./data/0-koda-gtfs-rt/tu/{params['date']}.7z"""

    # Trip Updates
    if os.path.exists(file_path_tu):
        print(date+" TU Exists")
    else:
        received = False
        while received == False:

            response_tu = requests.get('https://api.koda.trafiklab.se/KoDa/api/v2/gtfs-rt/sl/TripUpdates', 
                            params=params, headers=headers)
            print(type(response_tu.status_code), response_tu.status_code)

            if response_tu.status_code == 400:
                print(date + "TU: Does not exist, skipping")
                received=True
                continue;
                
            if response_tu.status_code != 200:
                print(date + " TU: Sleeping and trying again")
                time.sleep(10)
                
            if response_tu.status_code == 200: 
                received = True
                print(date + "TU: Fetching ")
                with open(file_path_tu, 'wb') as file:
                    file.write(response_tu.content)


    # Vehicle Positions
    if os.path.exists(file_path_vp):
        print(date+" VP Exists")
    else:
        received = False
        while received == False:

            response_vp = requests.get('https://api.koda.trafiklab.se/KoDa/api/v2/gtfs-rt/sl/VehiclePositions', 
                                    params=params, headers=headers)
            print(type(response_vp.status_code), response_vp.status_code)

            if response_vp.status_code == 400:
                print(date + "VP: Does not exist, skipping")
                received=True
                continue;
                
            if response_vp.status_code != 200:
                print(date + "VP: Sleeping and trying again")
                time.sleep(10)

            if response_vp.status_code == 200:
                received = True
                print(date + " VP: Fetching")
                with open(file_path_vp, 'wb') as file:
                    file.write(response_vp.content)
# Out:
#   0%|          | 0/153 [00:00<?, ?it/s]
# 2021-06-01 TU Exists
# 2021-06-01 VP Exists
# 2021-06-02 TU Exists
# 2021-06-02 VP Exists
# 2021-06-03 TU Exists
# 2021-06-03 VP Exists
# 2021-06-04 TU Exists
# 2021-06-04 VP Exists
# 2021-06-05 TU Exists
# 2021-06-05 VP Exists
# 2021-06-06 TU Exists
# 2021-06-06 VP Exists
# 2021-06-07 TU Exists
# 2021-06-07 VP Exists
# 2021-06-08 TU Exists
# 2021-06-08 VP Exists
# 2021-06-09 TU Exists
# 2021-06-09 VP Exists
# 2021-06-10 TU Exists
# 2021-06-10 VP Exists
# 2021-06-11 TU Exists
# 2021-06-11 VP Exists
# 2021-06-12 TU Exists
# 2021-06-12 VP Exists
# 2021-06-13 TU Exists
# 2021-06-13 VP Exists
# 2021-06-14 TU Exists
# 2021-06-14 VP Exists
# 2021-06-15 TU Exists
# 2021-06-15 VP Exists
# 2021-06-16 TU Exists
# 2021-06-16 VP Exists
# 2021-06-17 TU Exists
# 2021-06-17 VP Exists
# 2021-06-18 TU Exists
# 2021-06-18 VP Exists
# 2021-06-19 TU Exists
# 2021-06-19 VP Exists
# 2021-06-20 TU Exists
# 2021-06-20 VP Exists
# 2021-06-21 TU Exists
# 2021-06-21 VP Exists
# 2021-06-22 TU Exists
# 2021-06-22 VP Exists
# 2021-06-23 TU Exists
# 2021-06-23 VP Exists
# 2021-06-24 TU Exists
# 2021-06-24 VP Exists
# 2021-06-25 TU Exists
# 2021-06-25 VP Exists
# 2021-06-26 TU Exists
# 2021-06-26 VP Exists
# <class 'int'> 400
# 2021-06-27TU: Does not exist, skipping
# <class 'int'> 400
# 2021-06-27VP: Does not exist, skipping
# 2021-06-28 TU Exists
# 2021-06-28 VP Exists
# 2021-06-29 TU Exists
# 2021-06-29 VP Exists
# 2021-06-30 TU Exists
# 2021-06-30 VP Exists
# 2021-07-01 TU Exists
# 2021-07-01 VP Exists
# <class 'int'> 400
# 2021-07-02TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-02VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-03TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-03VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-04TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-04VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-05TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-05VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-06TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-06VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-07TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-07VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-08TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-08VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-09TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-09VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-10TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-10VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-11TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-11VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-12TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-12VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-13TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-13VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-14TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-14VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-15TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-15VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-16TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-16VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-17TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-17VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-18TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-18VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-19TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-19VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-20TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-20VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-21TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-21VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-22TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-22VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-23TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-23VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-24TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-24VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-25TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-25VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-26TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-26VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-27TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-27VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-28TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-28VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-29TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-29VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-30TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-30VP: Does not exist, skipping
# <class 'int'> 400
# 2021-07-31TU: Does not exist, skipping
# <class 'int'> 400
# 2021-07-31VP: Does not exist, skipping
# 2021-10-01 TU Exists
# 2021-10-01 VP Exists
# 2021-10-02 TU Exists
# 2021-10-02 VP Exists
# 2021-10-03 TU Exists
# 2021-10-03 VP Exists
# 2021-10-04 TU Exists
# 2021-10-04 VP Exists
# 2021-10-05 TU Exists
# 2021-10-05 VP Exists
# 2021-10-06 TU Exists
# 2021-10-06 VP Exists
# 2021-10-07 TU Exists
# 2021-10-07 VP Exists
# 2021-10-08 TU Exists
# 2021-10-08 VP Exists
# 2021-10-09 TU Exists
# 2021-10-09 VP Exists
# 2021-10-10 TU Exists
# 2021-10-10 VP Exists
# 2021-10-11 TU Exists
# 2021-10-11 VP Exists
# 2021-10-12 TU Exists
# 2021-10-12 VP Exists
# 2021-10-13 TU Exists
# 2021-10-13 VP Exists
# 2021-10-14 TU Exists
# 2021-10-14 VP Exists
# 2021-10-15 TU Exists
# 2021-10-15 VP Exists
# 2021-10-16 TU Exists
# 2021-10-16 VP Exists
# 2021-10-17 TU Exists
# 2021-10-17 VP Exists
# 2021-10-18 TU Exists
# 2021-10-18 VP Exists
# 2021-10-19 TU Exists
# 2021-10-19 VP Exists
# 2021-10-20 TU Exists
# 2021-10-20 VP Exists
# 2021-10-21 TU Exists
# 2021-10-21 VP Exists
# 2021-10-22 TU Exists
# 2021-10-22 VP Exists
# 2021-10-23 TU Exists
# 2021-10-23 VP Exists
# 2021-10-24 TU Exists
# 2021-10-24 VP Exists
# 2021-10-25 TU Exists
# 2021-10-25 VP Exists
# 2021-10-26 TU Exists
# 2021-10-26 VP Exists
# 2021-10-27 TU Exists
# 2021-10-27 VP Exists
# 2021-10-28 TU Exists
# 2021-10-28 VP Exists
# 2021-10-29 TU Exists
# 2021-10-29 VP Exists
# 2021-10-30 TU Exists
# 2021-10-30 VP Exists
# 2021-10-31 TU Exists
# 2021-10-31 VP Exists
# 2021-11-01 TU Exists
# 2021-11-01 VP Exists
# 2021-11-02 TU Exists
# 2021-11-02 VP Exists
# 2021-11-03 TU Exists
# 2021-11-03 VP Exists
# 2021-11-04 TU Exists
# 2021-11-04 VP Exists
# 2021-11-05 TU Exists
# 2021-11-05 VP Exists
# 2021-11-06 TU Exists
# 2021-11-06 VP Exists
# 2021-11-07 TU Exists
# 2021-11-07 VP Exists
# 2021-11-08 TU Exists
# 2021-11-08 VP Exists
# 2021-11-09 TU Exists
# 2021-11-09 VP Exists
# 2021-11-10 TU Exists
# 2021-11-10 VP Exists
# 2021-11-11 TU Exists
# 2021-11-11 VP Exists
# 2021-11-12 TU Exists
# 2021-11-12 VP Exists
# 2021-11-13 TU Exists
# 2021-11-13 VP Exists
# 2021-11-14 TU Exists
# 2021-11-14 VP Exists
# 2021-11-15 TU Exists
# 2021-11-15 VP Exists
# 2021-11-16 TU Exists
# 2021-11-16 VP Exists
# 2021-11-17 TU Exists
# 2021-11-17 VP Exists
# 2021-11-18 TU Exists
# 2021-11-18 VP Exists
# 2021-11-19 TU Exists
# 2021-11-19 VP Exists
# 2021-11-20 TU Exists
# 2021-11-20 VP Exists
# 2021-11-21 TU Exists
# 2021-11-21 VP Exists
# 2021-11-22 TU Exists
# 2021-11-22 VP Exists
# 2021-11-23 TU Exists
# 2021-11-23 VP Exists
# 2021-11-24 TU Exists
# 2021-11-24 VP Exists
# 2021-11-25 TU Exists
# 2021-11-25 VP Exists
# 2021-11-26 TU Exists
# 2021-11-26 VP Exists
# 2021-11-27 TU Exists
# 2021-11-27 VP Exists
# 2021-11-28 TU Exists
# 2021-11-28 VP Exists
# 2021-11-29 TU Exists
# 2021-11-29 VP Exists
# 2021-11-30 TU Exists
# 2021-11-30 VP Exists
# 2021-12-01 TU Exists
# 2021-12-01 VP Exists
# 2021-12-02 TU Exists
# 2021-12-02 VP Exists
# 2021-12-03 TU Exists
# 2021-12-03 VP Exists
# 2021-12-04 TU Exists
# 2021-12-04 VP Exists
# 2021-12-05 TU Exists
# 2021-12-05 VP Exists
# 2021-12-06 TU Exists
# 2021-12-06 VP Exists
# 2021-12-07 TU Exists
# 2021-12-07 VP Exists
# 2021-12-08 TU Exists
# 2021-12-08 VP Exists
# 2021-12-09 TU Exists
# 2021-12-09 VP Exists
# 2021-12-10 TU Exists
# 2021-12-10 VP Exists
# 2021-12-11 TU Exists
# 2021-12-11 VP Exists
# 2021-12-12 TU Exists
# 2021-12-12 VP Exists
# 2021-12-13 TU Exists
# 2021-12-13 VP Exists
# 2021-12-14 TU Exists
# 2021-12-14 VP Exists
# 2021-12-15 TU Exists
# 2021-12-15 VP Exists
# 2021-12-16 TU Exists
# 2021-12-16 VP Exists
# 2021-12-17 TU Exists
# 2021-12-17 VP Exists
# 2021-12-18 TU Exists
# 2021-12-18 VP Exists
# 2021-12-19 TU Exists
# 2021-12-19 VP Exists
# 2021-12-20 TU Exists
# 2021-12-20 VP Exists
# 2021-12-21 TU Exists
# 2021-12-21 VP Exists
# 2021-12-22 TU Exists
# 2021-12-22 VP Exists
# 2021-12-23 TU Exists
# <class 'int'> 400
# 2021-12-23VP: Does not exist, skipping
# 2021-12-24 TU Exists
# <class 'int'> 400
# 2021-12-24VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-25TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-25VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-26TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-26VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-27TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-27VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-28TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-28VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-29TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-29VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-30TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-30VP: Does not exist, skipping
# <class 'int'> 400
# 2021-12-31TU: Does not exist, skipping
# <class 'int'> 400
# 2021-12-31VP: Does not exist, skipping
